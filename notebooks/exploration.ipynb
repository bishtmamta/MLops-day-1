# %%
import pandas as pd
import numpy as numpy

df=pd.read_csv("C:\\Users\\princ\\MLops day 1\\data\\Advertising.csv")
df.head()
# Out:
# Running cells with 'MLops_env (Python 3.13.15)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\princ\MLops day 1\MLops_env ipykernel --update-deps --force-reinstall'
